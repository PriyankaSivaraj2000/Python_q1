# %%
pos=input("Enter the current position")
#pos='D4'
#u_pos1='B3'
#u_pos2='C2'
upos=input("Enter the user’s chess pieces")
ulist=upos.split(",")
#ulist.append(u_pos1)
#ulist.append(u_pos2)
opos=input("Enter the opponent’s chess pieces")
olist=opos.split(",")
#print(olist)
possi=[]
lpos=list(pos)

npos=int(lpos[1])
p1=npos+2
alp=ord(lpos[0])
a1=alp+1
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o1=a1+str(p1)
    #print(o1)
    possi.append(o1)

p1=npos-2
a1=alp+1
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o2=a1+str(p1)
    possi.append(o2)

p1=npos-2
a1=alp-1
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o3=a1+str(p1)
    possi.append(o3)

p1=npos+2
a1=alp-1
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o4=a1+str(p1)
    possi.append(o4)

p1=npos+1
a1=alp-2
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o5=a1+str(p1)
    possi.append(o5)

p1=npos+1
a1=alp+2
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o6=a1+str(p1)
    possi.append(o6)

p1=npos-1
a1=alp+2
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o7=a1+str(p1)
    possi.append(o7)

p1=npos-1
a1=alp-2
if (a1>=65 and a1<=72)and(p1<=8 and p1>0):
    a1=chr(a1)
    o8=a1+str(p1)
    possi.append(o8)
#print(possi)

num=len(ulist)
for j in range(num):
    if ulist[j] in possi:
        possi.remove(ulist[j])
#print(possi)

for k in range(len(possi)-1):
    print(possi[k],end=",")
print(possi[-1])
# Out:
# Enter the current positionD4
# Enter the user’s chess piecesB3,C2
# Enter the opponent’s chess piecesF3,E6,C7
# E6,E2,C6,B5,F5,F3
